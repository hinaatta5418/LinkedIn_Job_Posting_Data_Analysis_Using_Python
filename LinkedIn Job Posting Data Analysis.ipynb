# %% [markdown]
# LinkedIn Job Posting

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("C:\\Users\\hinaa\\Documents\\Python_DS_Pro\\postings.csv")
df
# Out:
#                                               job_title  \
# 0                                  C# Software Engineer
# 1                      Software Implementation Engineer
# 2     Senior Software Engineer, Back End (Go, AWS, J...
# 3      Senior Manager, Software Engineering, Full Stack
# 4     Lead Software Engineer, Full Stack(JavaScript/...
# ...                                                 ...
# 9375  Software Engineer 3 - 6D6-Real Time Software E...
# 9376                      Real Time Software Engineer 3
# 9377  6J7BI4-Software Engineer 4 - 6D6-Real Time Sof...
# 9378  6J7BI4-Software Engineer 4 - 6D6-Real Time Sof...
# 9379  6J7BI3-Software Engineer 3 - 6D6-Real Time Sof...
#
#                                                 company      job_location  \
# 0                                          E Tech Group  West Chester, OH
# 1                                                Kardex    Cincinnati, OH
# ...

# %%
df.describe()
# Out:
#                        job_title            company       job_location  \
# count                       9380               9380               9380
# unique                      3870               3373               1618
# top     Senior Software Engineer  Jobs for Humanity  San Francisco, CA
# freq                         794                681                133
#
#                                                  job_link  first_seen  \
# count                                                9380        9380
# unique                                               9380           1
# top     https://www.linkedin.com/jobs/view/c%23-softwa...  2023-12-25
# freq                                                    1        9380
#
#        search_city search_country   job level job_type  \
# count         9380           9380        9380     9380
# unique         709              4           2        3
# top         Novato  United States  Mid senior   Onsite
# ...

# %%
df.isnull().sum()
# Out:
# job_title          0
# company            0
# job_location       0
# job_link           0
# first_seen         0
# search_city        0
# search_country     0
# job level          0
# job_type           0
# job_summary        4
# job_skills        13
# dtype: int64

# %%
del df['job_skills']
df
# Out:
#                                               job_title  \
# 0                                  C# Software Engineer
# 1                      Software Implementation Engineer
# 2     Senior Software Engineer, Back End (Go, AWS, J...
# 3      Senior Manager, Software Engineering, Full Stack
# 4     Lead Software Engineer, Full Stack(JavaScript/...
# ...                                                 ...
# 9375  Software Engineer 3 - 6D6-Real Time Software E...
# 9376                      Real Time Software Engineer 3
# 9377  6J7BI4-Software Engineer 4 - 6D6-Real Time Sof...
# 9378  6J7BI4-Software Engineer 4 - 6D6-Real Time Sof...
# 9379  6J7BI3-Software Engineer 3 - 6D6-Real Time Sof...
#
#                                                 company      job_location  \
# 0                                          E Tech Group  West Chester, OH
# 1                                                Kardex    Cincinnati, OH
# ...

# %%
df=df.dropna(subset=['job_summary'],how='any')
print(df)
# Out:
#                                               job_title  \
# 0                                  C# Software Engineer
# 1                      Software Implementation Engineer
# 2     Senior Software Engineer, Back End (Go, AWS, J...
# 3      Senior Manager, Software Engineering, Full Stack
# 4     Lead Software Engineer, Full Stack(JavaScript/...
# ...                                                 ...
# 9375  Software Engineer 3 - 6D6-Real Time Software E...
# 9376                      Real Time Software Engineer 3
# 9377  6J7BI4-Software Engineer 4 - 6D6-Real Time Sof...
# 9378  6J7BI4-Software Engineer 4 - 6D6-Real Time Sof...
# 9379  6J7BI3-Software Engineer 3 - 6D6-Real Time Sof...
#
#                                                 company      job_location  \
# 0                                          E Tech Group  West Chester, OH
# 1                                                Kardex    Cincinnati, OH
# ...

# %%
df.isnull().sum()
# Out:
# job_title         0
# company           0
# job_location      0
# job_link          0
# first_seen        0
# search_city       0
# search_country    0
# job level         0
# job_type          0
# job_summary       0
# dtype: int64

# %%
df.drop_duplicates()
df
# Out:
#                                               job_title  \
# 0                                  C# Software Engineer
# 1                      Software Implementation Engineer
# 2     Senior Software Engineer, Back End (Go, AWS, J...
# 3      Senior Manager, Software Engineering, Full Stack
# 4     Lead Software Engineer, Full Stack(JavaScript/...
# ...                                                 ...
# 9375  Software Engineer 3 - 6D6-Real Time Software E...
# 9376                      Real Time Software Engineer 3
# 9377  6J7BI4-Software Engineer 4 - 6D6-Real Time Sof...
# 9378  6J7BI4-Software Engineer 4 - 6D6-Real Time Sof...
# 9379  6J7BI3-Software Engineer 3 - 6D6-Real Time Sof...
#
#                                                 company      job_location  \
# 0                                          E Tech Group  West Chester, OH
# 1                                                Kardex    Cincinnati, OH
# ...

# %%
location_counts = df['job_location'].value_counts()

top_10_locations = location_counts.head(10)

# Plot the bar chart for the top 10 locations
top_10_locations.plot(kind='bar', color='yellow', edgecolor='black')  # Added edgecolor for better separation
plt.title('Distribution of Top 10 Job Locations')
plt.xlabel('Job Location')
plt.ylabel('Number of Job Postings')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better visibility
plt.grid(axis='y', linestyle='--', alpha=0.7)  # Add a horizontal grid for better reference
plt.show()

# %%
company_count=df['company'].value_counts()
top_10_company=company_count.head(10)
top_10_company.plot(kind="barh", color='skyblue', edgecolor='black')
plt.title('Company Distribution - Top 10 Companies')
plt.xlabel('Number of Job Postings')
plt.ylabel('company')
plt.show()

# %%
job_type_counts = df['job_type'].value_counts()
job_type_counts.plot(kind='pie', autopct='%1.1f%%', startangle=90, colors=['skyblue', 'lightcoral', 'lightgreen', 'lightpink', 'lightyellow'])
plt.title('Job Types Distribution')
plt.ylabel('')  
plt.show()

# %%
remote_df = df[df['job_type'] == 'Remote']
remote_location_counts = remote_df['job_location'].value_counts()
top_remote_locations = remote_location_counts.head(10)
top_remote_locations.sort_values().plot(kind='barh', color='skyblue', edgecolor='black')  
plt.title('Top Job Locations for Remote Work')
plt.xlabel('Number of Remote Job Postings')
plt.ylabel('Job Location')
plt.show()
